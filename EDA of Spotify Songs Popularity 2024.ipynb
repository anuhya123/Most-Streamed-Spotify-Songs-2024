# %% [markdown]
# # What is Exploratory Data Analysis?
#
# Exploratory Data Analysis (EDA) is a method of analyzing datasets to understand their main characteristics. It involves summarizing data features, detecting patterns, and uncovering relationships through visual and statistical techniques. EDA helps in gaining insights and formulating hypotheses for further analysis.
#
# In our data-driven processes, we prioritize refining our raw data through the crucial stages of EDA (Exploratory Data Analysis). Both data pre-processing and feature engineering play pivotal roles in this endeavor. EDA involves a comprehensive range of activities, including data integration, analysis, cleaning, transformation, and dimension reduction.
#
# Data pre-processing involves cleaning and preparing raw data to facilitate feature engineering. Meanwhile, feature engineering entails employing various techniques to manipulate the data. This may include adding or removing relevant features, handling missing data, encoding variables, and dealing with categorical variables, among other tasks.
#
# Undoubtedly, feature engineering is a critical task that significantly influences the outcome of a model. It involves crafting new features based on existing data while pre-processing primarily focuses on cleaning and organizing the data.
#
# Let’s look at how to perform EDA using python!
#
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # About the dataset -
# My dataset appears to contain information about music tracks, including metadata, popularity metrics from various platforms, and explicit content flags.
#
# Column Descriptions -
#
# Basic Track Information-
#
# Track: The title of the track. <br>
# Album Name: The album where the track is featured. <br>
# Artist: The primary artist or band associated with the track.<br>
# Release Date: The date when the track was released. <br>
# ISRC: International Standard Recording Code, a unique identifier for a sound recording.
#
# Popularity Metrics -
#
# All Time Rank: An overall ranking of the track based on unspecified criteria. <br>
# Track Score: A numerical score assigned to the track, likely based on popularity or other factors.<br>
# Spotify Streams: The number of streams on Spotify.<br>
# Spotify Playlist Count: The number of Spotify playlists the track is included in.<br>
# Spotify Playlist Reach: The potential audience reached through Spotify playlists.<br>
# Spotify Popularity: A Spotify-specific popularity metric.<br>
# YouTube Views: The number of views on YouTube.<br>
# YouTube Likes: The number of likes on YouTube.<br>
# TikTok Posts: The number of TikTok posts featuring the track. <br>
# TikTok Likes: The number of likes on TikTok for posts featuring the track. <br>
# TikTok Views: The number of views on TikTok for posts featuring the track. <br>
# YouTube Playlist Reach: The potential audience reached through YouTube playlists. <br>
# Apple Music Playlist Count: The number of Apple Music playlists the track is included in. <br>
# AirPlay Spins: The number of times the track was played on radio stations. <br>
# SiriusXM Spins: The number of times the track was played on SiriusXM radio. <br>
# Deezer Playlist Count: The number of Deezer playlists the track is included in. <br>
# Deezer Playlist Reach: The potential audience reached through Deezer playlists. <br>
# Amazon Playlist Count: The number of Amazon Music playlists the track is included in. <br>
# Pandora Streams: The number of streams on Pandora.<br>
# Pandora Track Stations: The number of Pandora stations where the track is played. <br>
# Soundcloud Streams: The number of streams on SoundCloud.<br>
# Shazam Counts: The number of times the track was identified using Shazam.<br>
# TIDAL Popularity: (No data available) Likely a popularity metric for TIDAL.<br>
#
# Additional Information -
#
# Explicit Track: A binary indicator, likely 1 for explicit content and 0 for clean.
#
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Step 1: Import Python Libraries -
#
# The first step involved in ML using python is understanding and playing around with our data using libraries.
#
# Import all libraries which are required for our analysis, such as Data Loading, Statistical analysis, Visualizations, Data Transformations, Merge and Joins, etc.

# %%
import pandas as pd # Data manipulation
import numpy as np #Numerical calculations

# %% [markdown]
# # Step 2: Reading Dataset -
#
# The Pandas library offers a wide range of possibilities for loading data into the pandas DataFrame from files like JSON, .csv, .xlsx, .sql, .pickle, .html, .txt, images etc.
#
# Most of the data are available in a tabular format of CSV files. It is trendy and easy to access. Using the read_csv() function, data can be converted to a pandas DataFrame.

# %%
df = pd.read_csv("Most Streamed Spotify Songs 2024.csv")
df.head() #First 5 records of the dataset
# Out:
#                         Track                    Album Name          Artist
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman  \
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                     Houdini                       Houdini          Eminem
#
#   Release Date          ISRC  All Time Rank  Track Score  Spotify Streams
# 0    4/26/2024  QM24S2402528              1          725     3.904709e+08  \
# 1     5/4/2024  USUG12400910              2          546     3.237039e+08
# 2    3/19/2024  QZJ842400387              3          538     6.013093e+08
# 3    1/12/2023  USSM12209777              4          445     2.031281e+09
# 4    5/31/2024  USUG12403398              5          423     1.070349e+08
#
# ...

# %%
df.tail() #Last 5 records of the dataset
# Out:
#                                 Track                        Album Name
# 4595                For the Last Time                 For the Last Time  \
# 4596                 Dil Meri Na Sune  Dil Meri Na Sune (From "Genius")
# 4597            Grace (feat. 42 Dugg)                           My Turn
# 4598              Nashe Si Chadh Gayi             November Top 10 Songs
# 4599  Me Acostumbre (feat. Bad Bunny)   Me Acostumbre (feat. Bad Bunny)
#
#             Artist Release Date          ISRC  All Time Rank  Track Score
# 4595   $uicideboy$     9/5/2017  QM8DG1703420           4585           19  \
# 4596    Atif Aslam    7/27/2018  INT101800122           4575           19
# 4597      Lil Baby    2/28/2020  USUG12000043           4571           19
# 4598  Arijit Singh    11/8/2016  INY091600067           4591           19
# 4599     Arcï¿½ï¿½    4/11/2017  USB271700107           4593           19
#
#       Spotify Streams  Spotify Playlist Count  Spotify Playlist Reach  ...
# ...

# %%
print(df.shape)
# Out:
# (4600, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   int64
#  6   Track Score                 4600 non-null   int64
#  7   Spotify Streams             4487 non-null   float64
#  8   Spotify Playlist Count      4530 non-null   float64
#  9   Spotify Playlist Reach      4528 non-null   float64
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   float64
#  12  YouTube Likes               4285 non-null   float64
# ...

# %%
#Check for Duplication
# nunique() based on several unique values in each column and the data description,
# we can identify the continuous and categorical columns in the data. Duplicated data
#can be handled or removed based on further analysis.

df.nunique()
# Out:
# Track                         4370
# Album Name                    4005
# Artist                        1999
# Release Date                  1562
# ISRC                          4598
# All Time Rank                 4577
# Track Score                    206
# Spotify Streams               4425
# Spotify Playlist Count        4207
# Spotify Playlist Reach        4478
# Spotify Popularity              94
# YouTube Views                 4290
# YouTube Likes                 4283
# TikTok Posts                  3318
# TikTok Likes                  3615
# TikTok Views                  3616
# YouTube Playlist Reach        3458
# Apple Music Playlist Count     322
# AirPlay Spins                 3267
# SiriusXM Spins                 689
# Deezer Playlist Count          233
# Deezer Playlist Reach         3558
# Amazon Playlist Count          147
# Pandora Streams               3491
# Pandora Track Stations        2975
# Soundcloud Streams            1265
# Shazam Counts                 4002
# ...

# %%
# Missing Values Calculation
# isnull() is widely been in all pre-processing steps to identify null values in the data

#In our example, data.isnull().sum() is used to get the number of missing records in each column

df.isnull().sum()
# Out:
# Track                            0
# Album Name                       0
# Artist                           5
# Release Date                     0
# ISRC                             0
# All Time Rank                    0
# Track Score                      0
# Spotify Streams                113
# Spotify Playlist Count          70
# Spotify Playlist Reach          72
# Spotify Popularity             804
# YouTube Views                  308
# YouTube Likes                  315
# TikTok Posts                  1173
# TikTok Likes                   980
# TikTok Views                   981
# YouTube Playlist Reach        1009
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# SiriusXM Spins                2123
# Deezer Playlist Count          921
# Deezer Playlist Reach          928
# Amazon Playlist Count         1055
# Pandora Streams               1106
# Pandora Track Stations        1268
# Soundcloud Streams            3333
# Shazam Counts                  577
# ...

# %%
#This code helps to calculate the percentage of missing values in each column

(df.isnull().sum()/(len(df)))*100
# Out:
# Track                           0.000000
# Album Name                      0.000000
# Artist                          0.108696
# Release Date                    0.000000
# ISRC                            0.000000
# All Time Rank                   0.000000
# Track Score                     0.000000
# Spotify Streams                 2.456522
# Spotify Playlist Count          1.521739
# Spotify Playlist Reach          1.565217
# Spotify Popularity             17.478261
# YouTube Views                   6.695652
# YouTube Likes                   6.847826
# TikTok Posts                   25.500000
# TikTok Likes                   21.304348
# TikTok Views                   21.326087
# YouTube Playlist Reach         21.934783
# Apple Music Playlist Count     12.195652
# AirPlay Spins                  10.826087
# SiriusXM Spins                 46.152174
# Deezer Playlist Count          20.021739
# Deezer Playlist Reach          20.173913
# Amazon Playlist Count          22.934783
# ...

# %% [markdown]
# # Step 3: Data Reduction -
#
# Some columns or variables can be dropped if they do not add value to our analysis.
#
# In our dataset, the column TIDAL Popularity, assuming they don’t have any predictive power to predict the dependent variable, is being removed.

# %%
# Remove S.No. column from data
df = df.drop(['TIDAL Popularity', 'Explicit Track', 'SiriusXM Spins', 'Soundcloud Streams'], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   object
#  1   Album Name                  4600 non-null   object
#  2   Artist                      4595 non-null   object
#  3   Release Date                4600 non-null   object
#  4   ISRC                        4600 non-null   object
#  5   All Time Rank               4600 non-null   int64
#  6   Track Score                 4600 non-null   int64
#  7   Spotify Streams             4487 non-null   float64
#  8   Spotify Playlist Count      4530 non-null   float64
#  9   Spotify Playlist Reach      4528 non-null   float64
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   float64
#  12  YouTube Likes               4285 non-null   float64
# ...

# %%
df = df.dropna(axis = 0, how ='any')

#Rechecking our data for missing values or null values count
print(df.isnull().sum())

print(df.shape)
# Out:
# Track                         0
# Album Name                    0
# Artist                        0
# Release Date                  0
# ISRC                          0
# All Time Rank                 0
# Track Score                   0
# Spotify Streams               0
# Spotify Playlist Count        0
# Spotify Playlist Reach        0
# Spotify Popularity            0
# YouTube Views                 0
# YouTube Likes                 0
# TikTok Posts                  0
# TikTok Likes                  0
# TikTok Views                  0
# YouTube Playlist Reach        0
# Apple Music Playlist Count    0
# AirPlay Spins                 0
# Deezer Playlist Count         0
# Deezer Playlist Reach         0
# Amazon Playlist Count         0
# Pandora Streams               0
# Pandora Track Stations        0
# Shazam Counts                 0
# dtype: int64
# (2072, 25)

# %%
df
# Out:
#                                 Track                       Album Name
# 0                 MILLION DOLLAR BABY     Million Dollar Baby - Single  \
# 1                         Not Like Us                      Not Like Us
# 2          i like the way you kiss me       I like the way you kiss me
# 3                             Flowers                 Flowers - Single
# 5                         Lovin On Me                      Lovin On Me
# ...                               ...                              ...
# 4584                           Morado                           Morado
# 4590                         Daylight                    Harry's House
# 4591                    Happiest Year          Feel Something (Deluxe)
# 4597            Grace (feat. 42 Dugg)                          My Turn
# 4599  Me Acostumbre (feat. Bad Bunny)  Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score
# ...

# %% [markdown]
# # Step 4: Feature Engineering -
#
# Feature engineering refers to the process of using domain knowledge to select and transform the most relevant variables from raw data when creating a predictive model using machine learning or statistical modeling. The main goal of Feature engineering is to create meaningful data from raw data.

# %% [markdown]
# # Step 5: Creating Features -
#
# We will play around with the variable Release Date in our dataset. If we see the sample data, the column shows the release date of the song/track.
#
# It wont help us much or becomes difficult to analyze the data. Hence, we will create new features like day, month and year for more better analysis.

# %%
# Convert 'Release Date' to datetime format
df['Release Date'] = pd.to_datetime(df['Release Date'])

# Extract day, month, and year
df['Day'] = df['Release Date'].dt.day
df['Month'] = df['Release Date'].dt.month
df['Year'] = df['Release Date'].dt.year

# %%
df
# Out:
#                                 Track                       Album Name
# 0                 MILLION DOLLAR BABY     Million Dollar Baby - Single  \
# 1                         Not Like Us                      Not Like Us
# 2          i like the way you kiss me       I like the way you kiss me
# 3                             Flowers                 Flowers - Single
# 5                         Lovin On Me                      Lovin On Me
# ...                               ...                              ...
# 4584                           Morado                           Morado
# 4590                         Daylight                    Harry's House
# 4591                    Happiest Year          Feel Something (Deluxe)
# 4597            Grace (feat. 42 Dugg)                          My Turn
# 4599  Me Acostumbre (feat. Bad Bunny)  Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score
# ...

# %% [markdown]
# An ISRC code consists of 12 characters divided into four parts: <br>
# CountryCode (2 characters): Represents the country where the recording was first released.<br>
# Registrant Code (3 characters): Identifies the owner or administrator of the recording.<br>
# Year of Release (2 characters): Indicates the year the recording was first released.<br>
# Serial Number (5 characters): A unique number assigned by the registrant to the recording.<br>
#
# Based on this, a file with all the country codes and the agency name and location of the agency is pulled into our data analysis. From this file, we will map the country code with the existing data frame and create a new column with the Country name i.e., Location of the agency.

# %%
df['Country Code'] = df['ISRC'].str[:2]
df['ISRC_Registrant_Code'] = df['ISRC'].str[2:5]
df['ISRC_Year'] = df['ISRC'].str[5:7]
df['ISRC_Serial_Number'] = df['ISRC'].str[7:]
df
# Out:
#                                 Track                       Album Name
# 0                 MILLION DOLLAR BABY     Million Dollar Baby - Single  \
# 1                         Not Like Us                      Not Like Us
# 2          i like the way you kiss me       I like the way you kiss me
# 3                             Flowers                 Flowers - Single
# 5                         Lovin On Me                      Lovin On Me
# ...                               ...                              ...
# 4584                           Morado                           Morado
# 4590                         Daylight                    Harry's House
# 4591                    Happiest Year          Feel Something (Deluxe)
# 4597            Grace (feat. 42 Dugg)                          My Turn
# 4599  Me Acostumbre (feat. Bad Bunny)  Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score
# ...

# %%
df1 = pd.read_csv("ISRC CC.csv")
df1.head()
# Out:
#   Country Code          Name of Agency to which Allocated Location of Agency
# 0           AL  International ISRC Registration Authority            Albania
# 1           DZ  International ISRC Registration Authority            Algeria
# 2           AD  International ISRC Registration Authority            Andorra
# 3           AO  International ISRC Registration Authority             Angola
# 4           AI  International ISRC Registration Authority           Anguilla

# %%
df = pd.merge(df, df1, on='Country Code', how='left')

# Save the merged DataFrame to a new CSV file
df.to_csv('merged_data.csv', index=False)

df
# Out:
#                                 Track                       Album Name
# 0                 MILLION DOLLAR BABY     Million Dollar Baby - Single  \
# 1                         Not Like Us                      Not Like Us
# 2          i like the way you kiss me       I like the way you kiss me
# 3                             Flowers                 Flowers - Single
# 4                         Lovin On Me                      Lovin On Me
# ...                               ...                              ...
# 2069                           Morado                           Morado
# 2070                         Daylight                    Harry's House
# 2071                    Happiest Year          Feel Something (Deluxe)
# 2072            Grace (feat. 42 Dugg)                          My Turn
# 2073  Me Acostumbre (feat. Bad Bunny)  Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score
# ...

# %% [markdown]
# # Step 6: Data Cleaning/Wrangling -
#
# Some names of the variables are not relevant and not easy to understand. Some data may have data entry errors, and some variables may need data type conversion. We need to fix this issue in the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2074 entries, 0 to 2073
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Track                              2074 non-null   object
#  1   Album Name                         2074 non-null   object
#  2   Artist                             2074 non-null   object
#  3   Release Date                       2074 non-null   datetime64[ns]
#  4   ISRC                               2074 non-null   object
#  5   All Time Rank                      2074 non-null   int64
#  6   Track Score                        2074 non-null   int64
#  7   Spotify Streams                    2074 non-null   float64
#  8   Spotify Playlist Count             2074 non-null   float64
#  9   Spotify Playlist Reach             2074 non-null   float64
#  10  Spotify Popularity                 2074 non-null   float64
# ...

# %%
#My month column is represinting its values in the number form. 
#Instead, I want to change it to the month name for more easy analysis and visualization.

# Create a dictionary mapping month numbers to names
month_names = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10: 'October',
    11: 'November',
    12: 'December'
}

# Map the month numbers to their corresponding names
df['Month'] = df['Month'].map(month_names)

# %%
df
# Out:
#                                 Track                       Album Name
# 0                 MILLION DOLLAR BABY     Million Dollar Baby - Single  \
# 1                         Not Like Us                      Not Like Us
# 2          i like the way you kiss me       I like the way you kiss me
# 3                             Flowers                 Flowers - Single
# 4                         Lovin On Me                      Lovin On Me
# ...                               ...                              ...
# 2069                           Morado                           Morado
# 2070                         Daylight                    Harry's House
# 2071                    Happiest Year          Feel Something (Deluxe)
# 2072            Grace (feat. 42 Dugg)                          My Turn
# 2073  Me Acostumbre (feat. Bad Bunny)  Me Acostumbre (feat. Bad Bunny)
#
#               Artist Release Date          ISRC  All Time Rank  Track Score
# ...

# %%
#On proper observation, the year in the ISRC code does not match the year column from the release date for few records. 
#Hence, we are cleaning such data rows.

# Check if the last two digits of yyyy match yy and replace if necessary
df['Year'] = df.apply(lambda row: str(row['Year'])[:-2] + row['ISRC_Year'] if str(row['Year'])[-2:] != row['ISRC_Year'] else row['Year'], axis=1)

df.head()
# Out:
#                         Track                    Album Name          Artist
# 0         MILLION DOLLAR BABY  Million Dollar Baby - Single   Tommy Richman  \
# 1                 Not Like Us                   Not Like Us  Kendrick Lamar
# 2  i like the way you kiss me    I like the way you kiss me         Artemas
# 3                     Flowers              Flowers - Single     Miley Cyrus
# 4                 Lovin On Me                   Lovin On Me     Jack Harlow
#
#   Release Date          ISRC  All Time Rank  Track Score  Spotify Streams
# 0   2024-04-26  QM24S2402528              1          725     3.904709e+08  \
# 1   2024-05-04  USUG12400910              2          546     3.237039e+08
# 2   2024-03-19  QZJ842400387              3          538     6.013093e+08
# 3   2023-01-12  USSM12209777              4          445     2.031281e+09
# 4   2023-11-10  USAT22311371              6          410     6.706654e+08
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2074 entries, 0 to 2073
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Track                              2074 non-null   object
#  1   Album Name                         2074 non-null   object
#  2   Artist                             2074 non-null   object
#  3   Release Date                       2074 non-null   datetime64[ns]
#  4   ISRC                               2074 non-null   object
#  5   All Time Rank                      2074 non-null   int64
#  6   Track Score                        2074 non-null   int64
#  7   Spotify Streams                    2074 non-null   float64
#  8   Spotify Playlist Count             2074 non-null   float64
#  9   Spotify Playlist Reach             2074 non-null   float64
#  10  Spotify Popularity                 2074 non-null   float64
# ...

# %%
# Convert columns to numeric

df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['ISRC_Year'] = pd.to_numeric(df['ISRC_Year'], errors='coerce')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2074 entries, 0 to 2073
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Track                              2074 non-null   object
#  1   Album Name                         2074 non-null   object
#  2   Artist                             2074 non-null   object
#  3   Release Date                       2074 non-null   datetime64[ns]
#  4   ISRC                               2074 non-null   object
#  5   All Time Rank                      2074 non-null   int64
#  6   Track Score                        2074 non-null   int64
#  7   Spotify Streams                    2074 non-null   float64
#  8   Spotify Playlist Count             2074 non-null   float64
#  9   Spotify Playlist Reach             2074 non-null   float64
#  10  Spotify Popularity                 2074 non-null   float64
# ...

# %%
df.shape
# Out:
# (2074, 34)

# %% [markdown]
# Before we do EDA, lets separate Numerical and categorical variables for easy analysis

# %%
categorical = df.select_dtypes(include=['object']).columns
numerical = df.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(categorical)
print("Numerical Variables:")
print(numerical)
# Out:
# Categorical Variables:
# Index(['Track', 'Album Name', 'Artist', 'ISRC', 'Month', 'Country Code',
#        'ISRC_Registrant_Code', 'ISRC_Serial_Number',
#        'Name of Agency to which Allocated', 'Location of Agency'],
#       dtype='object')
# Numerical Variables:
# ['All Time Rank', 'Track Score', 'Spotify Streams', 'Spotify Playlist Count', 'Spotify Playlist Reach', 'Spotify Popularity', 'YouTube Views', 'YouTube Likes', 'TikTok Posts', 'TikTok Likes', 'TikTok Views', 'YouTube Playlist Reach', 'Apple Music Playlist Count', 'AirPlay Spins', 'Deezer Playlist Count', 'Deezer Playlist Reach', 'Amazon Playlist Count', 'Pandora Streams', 'Pandora Track Stations', 'Shazam Counts', 'Day', 'Year', 'ISRC_Year']

# %%
# CHecking if my categorical columns have any special characters. If yes, removing those rows.

special_chars_regex = r'[^a-zA-Z0-9\s]'

for col in categorical:
    mask = df[col].astype(str).str.contains(special_chars_regex)
    df = df[~mask]

df
# Out:
#                            Track                  Album Name           Artist
# 1                    Not Like Us                 Not Like Us   Kendrick Lamar  \
# 2     i like the way you kiss me  I like the way you kiss me          Artemas
# 4                    Lovin On Me                 Lovin On Me      Jack Harlow
# 5                      Gata Only                   Gata Only       FloyyMenor
# 7                          LUNCH        HIT ME HARD AND SOFT    Billie Eilish
# ...                          ...                         ...              ...
# 2063                 Traicionera                 Traicionera  Sebastian Yatra
# 2064                Already Dead                Already Dead       Juice WRLD
# 2066                       Focus                       Focus    Ariana Grande
# 2067            Fuentes de Ortiz  mix pa llorar en tu cuarto      Ed Maverick
# 2069                      Morado                      Morado         J Balvin
#
# ...

# %% [markdown]
# # Step 7: EDA Exploratory Data Analysis
#
# Exploratory Data Analysis refers to the crucial process of performing initial investigations on data to discover patterns to check assumptions with the help of summary statistics and graphical representations.
#
# EDA can be leveraged to check for outliers, patterns, and trends in the given data.
#
# EDA helps to find meaningful patterns in data.
#
# EDA provides in-depth insights into the data sets to solve our business problems.
#
# EDA gives a clue to impute missing values in the dataset

# %% [markdown]
# # Step 8: Statistics Summary -
#
# The information gives a quick and simple description of the data.
#
# Can include Count, Mean, Standard Deviation, median, mode, minimum value, maximum value, range, standard deviation, etc.
#
# Statistics summary gives a high-level idea to identify whether the data has any outliers, data entry error, distribution of data such as the data is normally distributed or left/right skewed
#
# In python, this can be achieved using describe()
#
# describe() function gives all statistics summary of data
#
# describe()– Provide a statistics summary of data belonging to numerical datatype such as int, float

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1013 entries, 1 to 2069
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Track                              1013 non-null   object
#  1   Album Name                         1013 non-null   object
#  2   Artist                             1013 non-null   object
#  3   Release Date                       1013 non-null   datetime64[ns]
#  4   ISRC                               1013 non-null   object
#  5   All Time Rank                      1013 non-null   int64
#  6   Track Score                        1013 non-null   int64
#  7   Spotify Streams                    1013 non-null   float64
#  8   Spotify Playlist Count             1013 non-null   float64
#  9   Spotify Playlist Reach             1013 non-null   float64
#  10  Spotify Popularity                 1013 non-null   float64
# ...

# %%
df.describe().T
# Out:
#                              count                           mean
# Release Date                  1013  2019-12-16 00:01:25.291214080  \
# All Time Rank               1013.0                     2009.30306
# Track Score                 1013.0                      48.977295
# Spotify Streams             1013.0               667218125.499506
# Spotify Playlist Count      1013.0                   94589.382034
# Spotify Playlist Reach      1013.0                32917845.267522
# Spotify Popularity          1013.0                      67.612043
# YouTube Views               1013.0               508116413.130306
# YouTube Likes               1013.0                 4063384.611056
# TikTok Posts                1013.0                  776225.778875
# TikTok Likes                1013.0               116381668.065153
# TikTok Views                1013.0               1137580052.66535
# YouTube Playlist Reach      1013.0               384857355.451135
# ...

# %%
#describe(include=’all’) provides a statistics summary of all data, include object, category etc

df.describe(include="all")
# Out:
#         Track        Album Name     Artist                   Release Date
# count    1013              1013       1013                           1013  \
# unique    994               917        474                            NaN
# top     Alone  Un Verano Sin Ti  Bad Bunny                            NaN
# freq        3                14         26                            NaN
# mean      NaN               NaN        NaN  2019-12-16 00:01:25.291214080
# min       NaN               NaN        NaN            1994-01-01 00:00:00
# 25%       NaN               NaN        NaN            2018-05-11 00:00:00
# 50%       NaN               NaN        NaN            2020-07-24 00:00:00
# 75%       NaN               NaN        NaN            2022-07-08 00:00:00
# max       NaN               NaN        NaN            2024-06-07 00:00:00
# std       NaN               NaN        NaN                            NaN
#
#                 ISRC  All Time Rank  Track Score  Spotify Streams
# ...

# %% [markdown]
# # Step 9: EDA Univariate Analysis
#
# Analyzing/visualizing the dataset by taking one variable at a time:
#
# Data visualization is essential; we must decide what charts to plot to better understand the data. In this, we visualize our data using Matplotlib and Seaborn libraries.
#
# Matplotlib is a Python 2D plotting library used to draw basic charts we use Matplotlib.
#
# Seaborn is also a python library built on top of Matplotlib that uses short lines of code to create and style statistical plots from Pandas and Numpy
#
# Univariate analysis can be done for both Categorical and Numerical variables.
#
# Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc.
#
# Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc.
#
# In our example, we have done a Univariate analysis using Histogram and  Box Plot for continuous Variables.
#
# In the below fig, a histogram and box plot is used to show the pattern of the variables, as some variables have skewness and outliers.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for col in numerical:
    print(col)
    print('Skew :', round(df[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    df[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.show()
# Out:
# All Time Rank
# Skew : 0.25
# Track Score
# Skew : 4.72
# Spotify Streams
# Skew : 1.84
# Spotify Playlist Count
# Skew : 1.59
# Spotify Playlist Reach
# Skew : 2.5
# Spotify Popularity
# Skew : -2.65
# YouTube Views
# Skew : 3.46
# YouTube Likes
# Skew : 3.27
# TikTok Posts
# Skew : 5.36
# TikTok Likes
# Skew : 9.52
# TikTok Views
# Skew : 11.86
# YouTube Playlist Reach
# Skew : 3.63
# Apple Music Playlist Count
# Skew : 2.65
# AirPlay Spins
# Skew : 4.64
# Deezer Playlist Count
# Skew : 4.63
# Deezer Playlist Reach
# Skew : 6.71
# Amazon Playlist Count
# Skew : 1.99
# Pandora Streams
# Skew : 2.64
# Pandora Track Stations
# Skew : 5.93
# Shazam Counts
# Skew : 2.86
# Day
# Skew : 0.13
# Year
# Skew : -1.49
# ISRC_Year
# Skew : 5.43

# %% [markdown]
# (.............................) are right skewed for this data to be transformed, and all outliers will be handled during imputation.
#
# What Skew Value Indicates -
#
# Skewness is a statistical measure that quantifies the asymmetry of a probability distribution. It tells you whether a dataset is symmetrical or skewed.
#
# Positive Skew (Skew > 0): The distribution has a long tail to the right. This indicates that there are more smaller values and fewer larger values.
#
# Negative Skew (Skew < 0): The distribution has a long tail to the left. This indicates that there are more larger values and fewer smaller values.
#
# Zero Skew (Skew ≈ 0): The distribution is approximately symmetrical.
#
# In summary, the skew value provides information about the shape of your data distribution. A positive or negative skew can influence the choice of statistical methods and interpretation of results.

# %%
for col in categorical:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=col, data=df)
    plt.title(f'Count Plot for {col}')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# # Step 10: Data Transformation
#
# Before we proceed to Bi-variate Analysis, Univariate analysis demonstrated the data pattern as some variables to be transformed.
#
# Identifying Variables for Transformation - Based on your provided skew values, several variables exhibit significant skewness:
#
# Highly Skewed Variables:
#
# Track Score: Skew of 4.72 indicates a strong positive skew.
#
# Spotify Streams, Spotify Playlist Count, Spotify Playlist Reach, YouTube Views, YouTube Likes, TikTok Posts, TikTok Likes, TikTok Views, YouTube Playlist Reach, Apple Music Playlist Count, AirPlay Spins, Deezer Playlist Count, Deezer Playlist Reach, Pandora Streams, Pandora Track Stations, Shazam Counts, ISRC_Year: All have high positive skew values, suggesting heavy right-tail distributions.
#
# Moderately Skewed Variables:
#
# Amazon Playlist Count: Skew of 1.99 indicates moderate positive skew.
# Negatively Skewed Variable:
#
# Spotify Popularity: Skew of -2.65 indicates a negative skew (long tail to the left).
#
# Log transformation can help in normalization, so this variable can maintain standard scale with other variables:

# %%
sns.distplot(df['Spotify Streams'], axlabel='Spotify Streams');
# Out:
# C:\Users\anual\AppData\Local\Temp\ipykernel_29268\2737976524.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Spotify Streams'], axlabel='Spotify Streams');

# %%
# Function for log transformation of the column
def log_transform(data,col):
    for colname in col:
        if (data[colname] == 1.0).all():
            data[colname + '_log'] = np.log(data[colname]+1)
        else:
            data[colname + '_log'] = np.log(data[colname])
    data.info()
    
log_transform(df,['Spotify Streams', 'Spotify Playlist Count'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1013 entries, 1 to 2069
# Data columns (total 36 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Track                              1013 non-null   object
#  1   Album Name                         1013 non-null   object
#  2   Artist                             1013 non-null   object
#  3   Release Date                       1013 non-null   datetime64[ns]
#  4   ISRC                               1013 non-null   object
#  5   All Time Rank                      1013 non-null   int64
#  6   Track Score                        1013 non-null   int64
#  7   Spotify Streams                    1013 non-null   float64
#  8   Spotify Playlist Count             1013 non-null   float64
#  9   Spotify Playlist Reach             1013 non-null   float64
#  10  Spotify Popularity                 1013 non-null   float64
# ...

# %%
#Log transformation of the feature 'Kilometers_Driven'
sns.distplot(df['Spotify Streams'], axlabel='Spotify Streams');
# Out:
# C:\Users\anual\AppData\Local\Temp\ipykernel_29268\857693392.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Spotify Streams'], axlabel='Spotify Streams');

# %%
plt.figure(figsize = (15, 4))
plt.subplot(1, 2, 1)
df['Spotify Streams'].hist(grid=False)
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# # Step 12: EDA Bivariate Analysis
#
# Now, let’s move ahead with bivariate analysis. Bivariate Analysis helps to understand how variables are related to each other and the relationship between dependent and independent variables present in the dataset.
#
# For Numerical variables, Pair plots and Scatter plots are widely been used to do Bivariate Analysis.
#
# A Stacked bar chart can be used for categorical variables if the output variable is a classifier. Bar plots can be used if the output variable is continuous

# %% [markdown]
# # Step 13: EDA Multivariate Analysis
#
# As the name suggests, Multivariate analysis looks at more than two variables. Multivariate analysis is one of the most useful methods to determine relationships and analyze patterns for any dataset.
#
# A heat map is widely been used for Multivariate Analysis
#
# Heat Map gives the correlation between the variables, whether it has a positive or negative correlation.

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(df.drop(categorical,axis=1).corr(), annot = True, vmin = -1, vmax = 1)
plt.show()
